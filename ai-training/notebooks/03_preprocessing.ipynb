# %% [markdown]
# # 03 - Preprocessing Pipeline
#
# ## SignBridge AI Training
#
# Preprocess the ISL dataset: frame extraction, normalization, splitting.
#
# **Objectives:**
# - Extract frames from videos
# - Apply normalization
# - Create train/val/test splits
# - Save preprocessed data

# %%
import sys
sys.path.insert(0, '../scripts')

from utils import load_config, set_seed
from preprocess import (
    extract_frames_from_video,
    normalize_frames,
    create_splits,
    save_processed_data,
)

config = load_config('dataset')
set_seed(42)
print(f'Preprocessing config loaded')

# %%
# Example preprocessing workflow (uncomment when data is available)
#
# 1. Load data source
# source_type = config['source']['type']
# if source_type == 'huggingface':
#     from utils import get_huggingface_dataset
#     dataset = get_huggingface_dataset(config)
#
# 2. Extract and normalize frames
# 3. Create splits
# 4. Save processed data

print('Preprocessing infrastructure ready. Uncomment cells when data is available.')

# %% [markdown]
# ## Next Steps
#
# - Load actual dataset
# - Run preprocessing pipeline
# - Verify processed data
# - Proceed to [04_model_training.ipynb](04_model_training.ipynb)
