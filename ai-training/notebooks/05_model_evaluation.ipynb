# %% [markdown]
# # 05 - Model Evaluation
#
# ## SignBridge AI Training
#
# Evaluate trained model performance.
#
# **Objectives:**
# - Compute accuracy, precision, recall, F1
# - Generate confusion matrix
# - Analyze per-class performance
# - Visualize training curves

# %%
import sys
sys.path.insert(0, '../scripts')

import numpy as np
from evaluate import (
    compute_metrics,
    compute_confusion_matrix,
    plot_confusion_matrix,
    plot_training_curves,
    generate_evaluation_report,
)
from utils import load_config, get_project_root

model_config = load_config('model')
num_classes = model_config.get('metadata', {}).get('num_classes', 35)
print(f'Evaluation ready. Num classes: {num_classes}')

# %%
# Example evaluation (uncomment when predictions are available)
#
# y_true = np.array([...])  # True labels
# y_pred = np.array([...])  # Predicted labels
#
# metrics = compute_metrics(y_true, y_pred, num_classes)
# report = generate_evaluation_report(metrics, class_names)
# print(report)
#
# cm = compute_confusion_matrix(y_true, y_pred, num_classes)
# plot_confusion_matrix(cm, class_names, output_path='confusion_matrix.png')

print('Evaluation infrastructure ready. Uncomment when model predictions are available.')

# %% [markdown]
# ## Next Steps
#
# - Load trained model
# - Run evaluation on test set
# - Generate evaluation report
# - Proceed to [06_export_model.ipynb](06_export_model.ipynb)
