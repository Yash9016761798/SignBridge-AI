# %% [markdown]
# # 02 - Pose & Landmark Analysis
#
# ## SignBridge AI Training
#
# Analyze MediaPipe landmark extraction on sample data.
#
# **Objectives:**
# - Test MediaPipe Hands and Pose on sample frames
# - Visualize extracted landmarks
# - Analyze landmark distributions
# - Determine optimal preprocessing parameters

# %%
import sys
sys.path.insert(0, '../scripts')

from utils import load_config
from extract_landmarks import LandmarkExtractor

config = load_config('dataset')
landmark_config = config.get('preprocessing', {}).get('landmarks', {})
print(f'Landmark config: {landmark_config}')

# %%
# Initialize MediaPipe extractor
extractor = LandmarkExtractor(landmark_config)
print('LandmarkExtractor initialized')
print(f'  Extract hands: {landmark_config.get("extract_hands", True)}')
print(f'  Extract pose: {landmark_config.get("extract_pose", True)}')
extractor.close()

# %% [markdown]
# ## Next Steps
#
# - Load sample video/image data
# - Run MediaPipe extraction
# - Visualize landmarks on frames
# - Proceed to [03_preprocessing.ipynb](03_preprocessing.ipynb)
