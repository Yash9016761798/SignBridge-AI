# %% [markdown]
# # 04 - Model Training
#
# ## SignBridge AI Training
#
# Define and train the ISL gesture recognition model.
#
# **Objectives:**
# - Define model architecture (LSTM/Transformer/CNN-LSTM)
# - Set up optimizer and scheduler
# - Train with checkpointing
# - Monitor training progress

# %%
import sys
sys.path.insert(0, '../scripts')

import torch
import torch.nn as nn
from utils import load_config, get_device, set_seed
from train import Trainer, MetricsTracker

training_config = load_config('training')
model_config = load_config('model')
set_seed(training_config['general']['seed'])
device = get_device(training_config['device']['type'])
print(f'Training config loaded. Device: {device}')

# %%
# Define model architecture (PLACEHOLDER - implement when ready to train)
#
# class ISLModel(nn.Module):
#     def __init__(self, config):
#         super().__init__()
#         # TODO: Implement based on model.yaml architecture
#         pass
#
#     def forward(self, x):
#         # TODO: Implement forward pass
#         pass

print('Model definition placeholder. Implement when ready to train.')

# %%
# Training loop (PLACEHOLDER)
#
# model = ISLModel(model_config)
# trainer = Trainer(training_config)
# criterion = nn.CrossEntropyLoss()
# optimizer = torch.optim.AdamW(model.parameters(), lr=0.001)
#
# trainer.train(model, train_loader, val_loader, criterion, optimizer)

print('Training loop placeholder. Implement when data and model are ready.')

# %% [markdown]
# ## Next Steps
#
# - Implement model architecture
# - Load preprocessed data
# - Run training
# - Proceed to [05_model_evaluation.ipynb](05_model_evaluation.ipynb)
